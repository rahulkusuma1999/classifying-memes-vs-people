# %%
from fastai.vision import *
from fastai import *

# %%
folder = 'memes'
file = 'downloadmemes_new.txt'

# %%
path = Path('data/pics')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
folder = 'people'
file = 'downloadpeople_new.txt'

# %%
path = Path('data/pics')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
download_images(path/file, dest, max_pics=200)

# %%
classes = ['memes','people']

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)
# Out:
# memes
# people

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.show_batch(rows=12, figsize=(7,8))
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor will change "

# %%
learn = cnn_learner(data, models.resnet34, metrics=accuracy)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# ...

# %%
learn.fit_one_cycle(8)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.342995</td>
#       <td>1.487689</td>
#       <td>0.578125</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.867160</td>
#       <td>0.965198</td>
#       <td>0.781250</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.673895</td>
#       <td>0.710692</td>
#       <td>0.843750</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.561240</td>
#       <td>0.544407</td>
#       <td>0.859375</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.457324</td>
#       <td>0.466963</td>
#       <td>0.890625</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='15' class='' max='25' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       60.00% [15/25 00:49<00:33]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(4, max_lr=slice(1e-4,1e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.094946</td>
#       <td>0.528987</td>
#       <td>0.890625</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.121958</td>
#       <td>0.550522</td>
#       <td>0.937500</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.105126</td>
#       <td>0.491939</td>
#       <td>0.953125</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.084209</td>
#       <td>0.481997</td>
#       <td>0.937500</td>
#       <td>00:03</td>
#     </tr>
#   </tbody>
# </table>
# ...

# %%
learn.save('stage-2')

# %%
learn.load('stage-2');

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
from fastai.widgets import *

# %%
db = (ImageList.from_folder(path)
                   .split_none()
                   .label_from_folder()
                   .transform(get_transforms(), size=224)
                   .databunch()
     )

# %%
learn_cln = cnn_learner(db, models.resnet34, metrics=accuracy)

# %%
learn_cln.load('stage-2');

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn_cln)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor will change "

# %%
ImageCleaner(ds, idxs, path)
# Out:
# ...
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %%
ds, idxs = DatasetFormatter().from_similars(learn_cln)
# Out:
# Getting activations...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [5/5 00:02<00:00]
#     </div>
# Computing similarities...

# %%
ImageCleaner(ds, idxs, path, duplicates=True)
# Out:
# ...
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %%
learn.export()

# %%
img = open_image(path/'guy.jpg')
img
# Out:
# Image (3, 232, 218)

# %%
learn = load_learner(path)

# %% [markdown]
# category tensor(0) for **memes**
#
# category tensor(1)  for **people**

# %%
pred_class,pred_idx,outputs = learn.predict(img) 
pred_class
# Out:
# Category tensor(1)

# %%
img = open_image(path/'meme2.jpg')
img
# Out:
# Image (3, 224, 224)

# %%
learn = load_learner(path)

# %%
pred_class,pred_idx,outputs = learn.predict(img) 
pred_class
# Out:
# Category tensor(0)
